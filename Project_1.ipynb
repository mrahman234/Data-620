# %% [markdown]
# # Project 1
# ## Mohammed Rahman
#
# ### Description
#
# For your first project, you are asked to
#
# Identify and load a network dataset that has some categorical information available for each node.
# For each of the nodes in the dataset, calculate degree centrality and eigenvector centrality.
# Compare your centrality measures across your categorical groups.
# For example, using the dataset from a study of romantic relationships among high school students in Columbus, Ohio [http://researchnews.osu.edu/archive/chains.htm], you might want to determine if there are any differences in your calculated centrality measures between the two sexes.  You might use a t-test or another statistical measure to support your findings.
#
# You may work in a small group.  Your project should be delivered in an Jupyter Notebook, and posted in GitHub.  Your project is due end of day Sunday. You and your team should created a video presentation about your project. You should be ready to present your project in our Meet-up.
#
#
# Youtube Presentation Link : https://youtu.be/EguXWPfS11Q

# %% [markdown]
# ### Overview
#
# NYC has a new initiative called Vision Zero. Its mission is to make New York City the world’s safest big city. One of the leading causes of injury-related death in New York City is being struck by a vehicle. Traffic related fatalities have decreased from 1990 - to 2011.
#
# One of Vision Zero’s initiates is the decrease in speed limits. Unless otherwise posted, the speed limit is 25MPH. The speed limit change was introduced  in 2014. In this data analysis.I'll look at a subset from 2011.
#
# The data is collected from NYC Open Data, more specificity the NYC NYPD Database, which can be found here: https://data.cityofnewyork.us/Public-Safety/NYPD-Motor-Vehicle-Collisions/h9gi-nxI. We decided to look atcent data - for 2019.

# %% [markdown]
# ## Libraries
#
# Loading the necessary libraries to perform network analysis.

# %%
import networkx as nx
from statistics import mean
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy import stats
import pandas as pd
import scipy.stats as stats
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
accidents = pd.read_csv("https://raw.githubusercontent.com/mrahman234/Data-620/main/Project%201/NYPD_Motor_Vehicle_Collisions_Crashes_2019.csv")
accidents.head(15)
# Out:
#         DATE        BOROUGH   LATITUDE  LONGITUDE  \
# 0   9/1/2019            NaN        NaN        NaN
# 1   9/1/2019            NaN  40.673676 -73.865760
# 2   9/1/2019            NaN  40.874600 -73.909700
# 3   9/1/2019            NaN        NaN        NaN
# 4   9/1/2019       BROOKLYN  40.665245 -73.875130
# 5   9/1/2019          BRONX        NaN        NaN
# 6   9/1/2019  STATEN ISLAND  40.552320 -74.190956
# 7   9/1/2019            NaN  40.749150 -73.988280
# 8   9/1/2019          BRONX  40.873394 -73.906710
# 9   9/1/2019          BRONX  40.853024 -73.884070
# 10  9/1/2019            NaN  40.836437 -73.918420
# 11  9/1/2019          BRONX  40.822105 -73.900620
# 12  9/1/2019            NaN  40.833940 -73.908700
# 13  9/1/2019       BROOKLYN  40.702070 -73.944230
# 14  9/1/2019            NaN  40.701450 -73.989624
#
#                        LOCATION                    ON_STREET_NAME  \
# 0                           NaN  NASSAU EXPRESSWAY
# 1   POINT (-73.86576 40.673676)  SUTTER AVENUE
# 2      POINT (-73.9097 40.8746)  BROADWAY
# 3                           NaN  GRAND CENTRAL PARKWAY
# 4   POINT (-73.87513 40.665245)  LINDEN BOULEVARD
# 5                           NaN  EAST FORDHAM ROAD
# 6   POINT (-74.190956 40.55232)                               NaN
# 7    POINT (-73.98828 40.74915)  AVENUE OF THE AMERICAS
# 8   POINT (-73.90671 40.873394)  WEST 225 STREET
# 9   POINT (-73.88407 40.853024)                               NaN
# 10  POINT (-73.91842 40.836437)  WALTON AVENUE
# 11  POINT (-73.90062 40.822105)  PROSPECT AVENUE
# 12    POINT (-73.9087 40.83394)  EAST 169 STREET
# 13   POINT (-73.94423 40.70207)                               NaN
# 14  POINT (-73.989624 40.70145)  BROOKLYN QUEENS EXPRESSWAY
#
#    CROSS STREET NAME                           OFF STREET NAME  \
# 0                NaN                                       NaN
# 1                NaN                                       NaN
# 2                NaN                                       NaN
# 3     UNION TURNPIKE                                       NaN
# 4      ATKINS AVENUE                                       NaN
# 5     BELMONT AVENUE                                       NaN
# 6                NaN  260       ARDEN AVENUE
# 7                NaN                                       NaN
# 8    EXTERIOR STREET                                       NaN
# 9                NaN  2358      CROTONA AVENUE
# 10               NaN                                       NaN
# 11   EAST 163 STREET                                       NaN
# 12               NaN                                       NaN
# 13               NaN  672       BROADWAY
# 14               NaN                                       NaN
#
#                 CONTRIBUTINGFACTOR CONTRIBUTING FACTOR VEHICLE 2  \
# 0   Driver Inattention/Distraction                           NaN
# 1                      Unspecified                           NaN
# 2               Pavement Defective                           NaN
# 3                      Unspecified                           NaN
# 4            Following Too Closely                   Unspecified
# 5   Driver Inattention/Distraction                   Unspecified
# 6          View Obstructed/Limited                   Unspecified
# 7      Traffic Control Disregarded                           NaN
# 8   Driver Inattention/Distraction                   Unspecified
# 9   Driver Inattention/Distraction                   Unspecified
# 10  Driver Inattention/Distraction                   Unspecified
# 11                     Unspecified                   Unspecified
# 12                     Unspecified                           NaN
# 13                    Unsafe Speed                   Unspecified
# 14            Unsafe Lane Changing                   Unspecified
#
#    CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
# 10                   Unspecified                           NaN
# 11                           NaN                           NaN
# 12                           NaN                           NaN
# 13                   Unspecified                           NaN
# 14                           NaN                           NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN       4198311
# 1                            NaN       4199346
# 2                            NaN       4197802
# 3                            NaN       4199721
# 4                            NaN       4199339
# 5                            NaN       4199427
# 6                            NaN       4198162
# 7                            NaN       4201656
# 8                            NaN       4198003
# 9                            NaN       4197979
# 10                           NaN       4198170
# 11                           NaN       4198144
# 12                           NaN       4198190
# 13                           NaN       4198832
# 14                           NaN       4200946
#
#                     VEHICLE TYPE CODE 1
# 0                                 Sedan
# 1                                 Sedan
# 2                                 Sedan
# 3                            Motorcycle
# 4                                 Sedan
# 5   Station Wagon/Sport Utility Vehicle
# 6   Station Wagon/Sport Utility Vehicle
# 7                                  Taxi
# 8                                 Sedan
# 9                                 Sedan
# 10  Station Wagon/Sport Utility Vehicle
# 11  Station Wagon/Sport Utility Vehicle
# 12                                Sedan
# 13  Station Wagon/Sport Utility Vehicle
# 14                                 Taxi

# %% [markdown]
# ## Data Wrangling
#
# Now transforming data, here created a new location variable and set it to On street name.

# %%
locations = accidents.ON_STREET_NAME.unique()
locations = pd.DataFrame(locations,columns=['ON_STREET_NAME'])
locations['ID'] = range(7000000,7000000+len(locations))
locations
# Out:
#                        ON_STREET_NAME       ID
# 0    NASSAU EXPRESSWAY                 7000000
# 1    SUTTER AVENUE                     7000001
# 2    BROADWAY                          7000002
# 3    GRAND CENTRAL PARKWAY             7000003
# 4    LINDEN BOULEVARD                  7000004
# ..                                ...      ...
# 288  SOUTH CONDUIT AVENUE              7000288
# 289  154 STREET                        7000289
# 290  EVELYN PLACE                      7000290
# 291  QUEENS BOULEVARD                  7000291
# 292  107 AVENUE                        7000292
#
# [293 rows x 2 columns]

# %% [markdown]
# Now, merging the locations and accidents dataset together on the "on_street_name" column.

# %%
n = accidents.loc[:,['COLLISION_ID', 'ON_STREET_NAME', 'CONTRIBUTINGFACTOR', 'VEHICLE TYPE CODE 1', 'LOCATION']]
t = pd.merge(n, locations, on="ON_STREET_NAME")
t
# Out:
#      COLLISION_ID                    ON_STREET_NAME  \
# 0         4198311  NASSAU EXPRESSWAY
# 1         4199346  SUTTER AVENUE
# 2         4199361  SUTTER AVENUE
# 3         4197802  BROADWAY
# 4         4198430  BROADWAY
# ..            ...                               ...
# 594       4198499  SOUTH CONDUIT AVENUE
# 595       4198614  154 STREET
# 596       4198530  EVELYN PLACE
# 597       4198489  QUEENS BOULEVARD
# 598       4199004  107 AVENUE
#
#                  CONTRIBUTINGFACTOR                  VEHICLE TYPE CODE 1  \
# 0    Driver Inattention/Distraction                                Sedan
# 1                       Unspecified                                Sedan
# 2    Passing or Lane Usage Improper  Station Wagon/Sport Utility Vehicle
# 3                Pavement Defective                                Sedan
# 4                       Unspecified                                 Bike
# ..                              ...                                  ...
# 594   Failure to Yield Right-of-Way  Station Wagon/Sport Utility Vehicle
# 595                Backing Unsafely                                Sedan
# 596   Failure to Yield Right-of-Way                                Sedan
# 597  Driver Inattention/Distraction                                 Taxi
# 598                     Unspecified                                Sedan
#
#                          LOCATION       ID
# 0                             NaN  7000000
# 1     POINT (-73.86576 40.673676)  7000001
# 2     POINT (-73.89987 40.668682)  7000001
# 3        POINT (-73.9097 40.8746)  7000002
# 4      POINT (-73.92122 40.86769)  7000002
# ..                            ...      ...
# 594   POINT (-73.72986 40.665348)  7000288
# 595  POINT (-73.811005 40.764706)  7000289
# 596   POINT (-73.90534 40.859642)  7000290
# 597    POINT (-73.87767 40.73675)  7000291
# 598    POINT (-73.78873 40.70003)  7000292
#
# [599 rows x 6 columns]

# %%
#create relation list between each case and the location of the occurrence
edgeList = t.loc[:,['COLLISION_ID', 'ID',  'CONTRIBUTINGFACTOR', 'LOCATION', 'ON_STREET_NAME']]

edgeList
# Out:
#      COLLISION_ID       ID              CONTRIBUTINGFACTOR  \
# 0         4198311  7000000  Driver Inattention/Distraction
# 1         4199346  7000001                     Unspecified
# 2         4199361  7000001  Passing or Lane Usage Improper
# 3         4197802  7000002              Pavement Defective
# 4         4198430  7000002                     Unspecified
# ..            ...      ...                             ...
# 594       4198499  7000288   Failure to Yield Right-of-Way
# 595       4198614  7000289                Backing Unsafely
# 596       4198530  7000290   Failure to Yield Right-of-Way
# 597       4198489  7000291  Driver Inattention/Distraction
# 598       4199004  7000292                     Unspecified
#
#                          LOCATION                    ON_STREET_NAME
# 0                             NaN  NASSAU EXPRESSWAY
# 1     POINT (-73.86576 40.673676)  SUTTER AVENUE
# 2     POINT (-73.89987 40.668682)  SUTTER AVENUE
# 3        POINT (-73.9097 40.8746)  BROADWAY
# 4      POINT (-73.92122 40.86769)  BROADWAY
# ..                            ...                               ...
# 594   POINT (-73.72986 40.665348)  SOUTH CONDUIT AVENUE
# 595  POINT (-73.811005 40.764706)  154 STREET
# 596   POINT (-73.90534 40.859642)  EVELYN PLACE
# 597    POINT (-73.87767 40.73675)  QUEENS BOULEVARD
# 598    POINT (-73.78873 40.70003)  107 AVENUE
#
# [599 rows x 5 columns]

# %% [markdown]
# ## Graph
#
# Now, using graph to analyze the data.

# %%
# create Nodes
G = nx.Graph()

# create occurrence nodes
for index, row in t.iterrows():
    G.add_node(row['COLLISION_ID'],factor=row['VEHICLE TYPE CODE 1'],block=row['ON_STREET_NAME'],location='')

# create Location Nodes
for index, row in locations.iterrows():
     G.add_node(row['ID'],location=row['ON_STREET_NAME'],case_number='',block='')

#create Edges
for index, row in edgeList.iterrows():
    G.add_edge(row['CONTRIBUTINGFACTOR'],row['ID'],relation = row['CONTRIBUTINGFACTOR'])

# create primary_type edges
# this will link similar occurrences
for accident in accidents.CONTRIBUTINGFACTOR.unique():
    ids = accidents.loc[accidents['CONTRIBUTINGFACTOR'] == accident].COLLISION_ID
    if(len(ids) > 1):
        for val in ids:
            # get other items to create edgeList
            e = [t for t in ids  if t != val]
            # create edge
            for relation in e:
                G.add_edge(val,relation,relation = accident)

# %%
#Plotting the graph
plt.figure(figsize=(20,15))
nx.draw_networkx(G)
plt.show()

# %% [markdown]
# When looking at the results, the eigenvector scores seem to be either high or low, relative to where an accident took place.

# %%
cf = pd.DataFrame()
cf['eig_centrality'] = nx.eigenvector_centrality(G).values()
cf['deg_centrality'] = nx.degree_centrality(G).values()
cf['bet_centrality'] = nx.betweenness_centrality(G).values()
cf['clo_centrality'] = nx.closeness_centrality(G).values()
cf.index = list(G)
cf
# Out:
#                                   eig_centrality  deg_centrality  \
# 4198311                             7.738232e-02        0.180043
# 4199346                             2.243933e-05        0.144252
# 4199361                             2.078603e-34        0.022777
# 4197802                             2.002713e-66        0.002169
# 4198430                             2.243933e-05        0.144252
# ...                                          ...             ...
# Accelerator Defective               6.575631e-47        0.001085
# Brakes Defective                    1.132714e-45        0.002169
# Pavement Slippery                   8.891446e-46        0.003254
# Lane Marking Improper/Inadequate    6.112828e-73        0.001085
# Using On Board Navigation Device    6.112828e-73        0.001085
#
#                                   bet_centrality  clo_centrality
# 4198311                                 0.000000        0.180043
# 4199346                                 0.000000        0.144252
# 4199361                                 0.000000        0.022777
# 4197802                                 0.000000        0.002169
# 4198430                                 0.000000        0.144252
# ...                                          ...             ...
# Accelerator Defective                   0.000000        0.070705
# Brakes Defective                        0.000749        0.090541
# Pavement Slippery                       0.001496        0.084575
# Lane Marking Improper/Inadequate        0.000000        0.001085
# Using On Board Navigation Device        0.000000        0.001085
#
# [923 rows x 4 columns]

# %% [markdown]
# ## Analysis
#
# After creating the graph, finally calculated the centrality measures for the nodes in the graph. Eigenvector centrality is a measure of centrality that takes into account the relative "influence" of neighboring nodes when determining the influence of any given node. This means that it isn't about the # of connections a given node has, but the connections a given node has to well connected nodes. A high eigenvector score means being connected to more influential nodes.
#
# Degree Centrality is simply a measure of the number of "degrees" a node has. A degree is an outside connection (an edge, linking the node to another node).
