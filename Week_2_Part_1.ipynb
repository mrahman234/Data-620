# %% [markdown]
# # Graph Visualization
# ## Mohammed Rahman
# ### Description
#
# This week's assignment is to:
#
# Load a graph database of your choosing from a text file or other source.  If you take a large network dataset from the web (such as from Stanford Large Network Dataset Collection), please feel free at this point to load just a small subset of the nodes and edg
# es.
# Create basic analysis on the graph, including the graph’s diameter, and at least one other metric of your choosing.  You may either code the functions by hand (to build your intuition and insight), or use functions in an existing packa
# ge.
# Use a visualization tool of your choice to display information. Use NetworkX directly or pyviz or another tool. You can try Gephi too if you like or Neo4j but you should get used to use the Python to
# olset
# Please record a short video (~ 5 minutes), and submit a link to the video in advance of our meet-up. You wll be showing your assignment in the meet-up but it always useful to have a recording.
#
# Youtube presentation Link: https://youtu.be/bzSg72hcpKs

# %% [markdown]
# ### Overview
# The dataset is taken from the https://snap.stanford.edu/data/ repository of datasets. I decided it would be interesting to analyze the ego-Facebook dataset. The Type is "Undirected", the # of nodes consist of 4,039. The # of edges consist of 88,234. The description for this dataset is: "Social circles from Facebook (anonymized).
#
# Facebook has a huge impact of todays society - from keeping up with family and friends, to networking with people around t country. I thought it would be interesting to take a look and see what the data might show us.s.

# %% [markdown]
# ### Libraries
#
# Loading the required libraries for the analysis.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
from pylab import rcParams
# %matplotlib inline

# %% [markdown]
# Now tha tthr libraries are loade. Ie can impor the  data into Python using the pandas function: read_table(.
#
# In order to load the data, I needed to convert first the .gz zim type file into a readable format. The below code converts teh file and reads it into a pandas dataframe.me

# %%
df = pd.read_table("https://raw.githubusercontent.com/mrahman234/Data-620/main/facebook_combined.txt",
                 compression='infer',
                 header=0, sep=' ',
                 names = ['source','target'])
df.head()
# Out:
#    source  target
# 0       0       2
# 1       0       3
# 2       0       4
# 3       0       5
# 4       0       6

# %%
df.shape
# Out:
# (88233, 2)

# %% [markdown]
# As we can see, there are 88,234 rows (edge list) worth of data. We're going to create a subset of this data to work with. I'll work with 100 rows of data, between rows 400-500.

# %%
df = df[300:400]
df.shape
# Out:
# (100, 2)

# %%
df.head()
# Out:
#      source  target
# 300       0     302
# 301       0     303
# 302       0     304
# 303       0     305
# 304       0     306

# %% [markdown]
# ### Graph Visualization
#
# Now, let's take a look at some basic graph information

# %%
# Graph Diameter
G = nx.from_pandas_edgelist(df)

nx.algorithms.diameter(G)
nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# A graph's diameter is the "largest # of vertices that must be traversed in order to travel from one vertex to another". in this case, the diameter is 8.

# %%
# Graph Distance
path = nx.shortest_path(G,source=5,target=4)

pos = nx.spring_layout(G)

nx.draw(G, pos, with_labels=True)
path_edges = zip(path,path[1:])
nx.draw_networkx_nodes(G,pos,nodelist=path,node_color='grey')
plt.show()

# %% [markdown]
# The graph distance is the shortest path that one must walk from A to B. Also known as the "simplest measure of distance".
# Here, n
# Nodes 5 and 4 seem to be the furthest from each other - lets take a look at the shortest distance between them. to traverse from nodes 5 to 4, one must pass through 5 other nodes.
